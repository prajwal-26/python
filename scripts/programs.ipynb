# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwal-26/python/blob/main/scripts/programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("machine learning")
# Out:
# machine learning
